# %% [markdown]
# # Load CheXpert Dataset
#
# This notebook imports the CheXpertDataset class from pyhealth/datasets/chexpert.py and shows how to instantiate it.
#
# Run the cells in order.

# %%
from pathlib import Path
import sys
import importlib.util

# Make sure the local PyHealth package is importable from this notebook.
# Notebook location: PyHealth/examples/rexkg/load_dataset.ipynb
# Package root:      PyHealth/
pyhealth_root = Path.cwd().resolve().parents[1]
if str(pyhealth_root) not in sys.path:
    sys.path.insert(0, str(pyhealth_root))

from pyhealth.datasets.chexpert import CheXpertDataset

print(f"Using PyHealth root: {pyhealth_root}")
print("Imported CheXpertDataset successfully")

# %%
# Set this to the folder that contains your CheXpert files.
# Required files for best results include:
# - df_chexpert_plus_240401.csv (or another recognized metadata CSV)
# - image files referenced by the CSV path_to_image column
# can be applied on data sets listed in RexKG research paper
chexpert_root = Path("/path/to/chexpert_root")

dataset = CheXpertDataset(root=str(chexpert_root))
print(dataset)

dataset.stat()
# Out:
# No config path provided, using default config
# Preparing CheXpert metadata...
# No raw CheXpert metadata file found in /path/to/chexpert_root. Please download from https://stanfordaimi.azurewebsites.net/datasets/5158c524-d3ab-4e02-96e9-6ee9efc110a1 and place df_chexpert_plus_240401.csv in the root directory.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[19], line 7
#       3 # - df_chexpert_plus_240401.csv (or another recognized metadata CSV)
#       4 # - image files referenced by the CSV path_to_image column
#       5 chexpert_root = Path("/path/to/chexpert_root")
#       6
# ----> 7 dataset = CheXpertDataset(root=str(chexpert_root))
#       8 print(dataset)
#       9
#      10 dataset.stat()
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/PyHealth/pyhealth/datasets/chexpert.py:89, in CheXpertDataset.__init__(self, root, tables, dataset_name, config_path, **kwargs)
#      87 if not os.path.exists(pyhealth_csv):
#      88     logger.info("Preparing CheXpert metadata...")
# ---> 89     self.prepare_metadata(root)
#      91 default_tables = ["chexpert"]
#      92 tables = default_tables + (tables or [])
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/PyHealth/pyhealth/datasets/chexpert.py:162, in CheXpertDataset.prepare_metadata(root)
#     134     logger.warning(
#     135         f"No raw CheXpert metadata file found in {root}. "
#     136         "Please download from "
#    (...)    139         "df_chexpert_plus_240401.csv in the root directory."
#     140     )
#     141     # Write an empty placeholder so subsequent loads don't re-trigger
#     142     pd.DataFrame(
#     143         columns=[
#     144             "deid_patient_id",
#     145             "path_to_image",
#     146             "frontal_lateral",
#     147             "ap_pa",
#     148             "patient_report_date_order",
#     149             "age",
#     150             "sex",
#     151             "race",
#     152             "ethnicity",
#     153             "interpreter_needed",
#     154             "insurance_type",
#     155             "recent_bmi",
#     156             "deceased",
#     157             "split",
#     158             "section_findings",
#     159             "section_impression",
#     160             "report",
#     161         ]
# --> 162     ).to_csv(os.path.join(root, "chexpert-pyhealth.csv"), index=False)
#     163     return
#     165 logger.info(f"Processing CheXpert metadata file: {raw_file}")
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/.venv/lib/python3.13/site-packages/pandas/core/generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/.venv/lib/python3.13/site-packages/pandas/io/formats/format.py:1025, in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1020             return content
#    1022         return None
# -> 1025 def save_to_buffer(
#    1026     string: str,
#    1027     buf: FilePath | WriteBuffer[str] | None = None,
#    1028     encoding: str | None = None,
#    1029 ) -> str | None:
#    1030     """
#    1031     Perform serialization. Write to buf or return as string if buf is None.
#    1032     """
#    1033     with _get_buffer(buf, encoding=encoding) as fd:
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/.venv/lib/python3.13/site-packages/pandas/io/formats/csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/.venv/lib/python3.13/site-packages/pandas/io/common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     783     handle = get_bz2_file()(  # type: ignore[call-overload]
#     784         handle,
#     785         mode=ioargs.mode,
#     786         **compression_args,
#     787     )
#     789 # ZIP Compression
#     790 elif compression == "zip":
#     791     # error: Argument 1 to "_BytesZipFile" has incompatible type
#     792     # "Union[str, BaseBuffer]"; expected "Union[Union[str, PathLike[str]],
# --> 793     # ReadBuffer[bytes], WriteBuffer[bytes]]"
#     794     handle = _BytesZipFile(
#     795         handle, ioargs.mode, **compression_args  # type: ignore[arg-type]
#     796     )
#     797     if handle.buffer.mode == "r":
#
# File /mnt/c/Users/Aarje/OneDrive - University of Illinois - Urbana/School/cs598_project/.venv/lib/python3.13/site-packages/pandas/io/common.py:652, in check_parent_directory(path)
#     634 @overload
#     635 def get_handle(
#     636     path_or_buf: FilePath | BaseBuffer,
#    (...)    644     storage_options: StorageOptions = ...,
#     645 ) -> IOHandles[str]:
#     646     ...
#     649 @overload
#     650 def get_handle(
#     651     path_or_buf: FilePath | BaseBuffer,
# --> 652     mode: str,
#     653     *,
#     654     encoding: str | None = ...,
#     655     compression: CompressionOptions = ...,
#     656     memory_map: bool = ...,
#     657     is_text: bool = ...,
#     658     errors: str | None = ...,
#     659     storage_options: StorageOptions = ...,
#     660 ) -> IOHandles[str] | IOHandles[bytes]:
#     661     ...
#     664 @doc(compression_options=_shared_docs["compression_options"] % "path_or_buf")
#     665 def get_handle(
#     666     path_or_buf: FilePath | BaseBuffer,
#    (...)    674     storage_options: StorageOptions | None = None,
#     675 ) -> IOHandles[str] | IOHandles[bytes]:
#
# OSError: Cannot save file into a non-existent directory: '/path/to/chexpert_root'

# %%
# Optional: build the default task and inspect one processed sample
samples = dataset.set_task()
print(f"Number of task samples: {len(samples)}")
if len(samples) > 0:
    print(samples[0])
