# %% [markdown]
# # GPT 4 Pipeline for RexKG system
# ## 1) declare the chosen dataset

# %%
# python gpt4_entity_extraction.py
# python gpt4_entity_relation.py

# may take a few mins to run to build cache
from pathlib import Path
import sys
import importlib.util


# Make sure the local PyHealth package is importable from this notebook.
# Notebook location: PyHealth/examples/rexkg/load_dataset.ipynb
# Package root:      PyHealth/
pyhealth_root = Path.cwd().resolve().parents[1]
if str(pyhealth_root) not in sys.path:
    sys.path.insert(0, str(pyhealth_root))

from pyhealth.datasets import RexKGCheXpertDataset
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 13
#       7 import importlib.util
#      10 # Make sure the local PyHealth package is importable from this notebook.
#      11 # Notebook location: PyHealth/examples/rexkg/load_dataset.ipynb
#      12 # Package root:      PyHealth/
# ---> 13 pyhealth_root = Path.cwd().resolve().parents[1]
#      14 if str(pyhealth_root) not in sys.path:
#      15     sys.path.insert(0, str(pyhealth_root))
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
# -> 1481 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1523, in _pydevd_sys_monitoring_cython._internal_line_event()
# -> 1523 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1324, in _pydevd_sys_monitoring_cython._stop_on_breakpoint()
# -> 1324 'Could not get source, probably due dynamically evaluated source code.'
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
# -> 1961 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/miniconda3/envs/cs598-pyhealth/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2199, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2196             from_this_thread.append(frame_custom_thread_id)
#    2198     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2199         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2201 frames_list = None
#    2203 if keep_suspended:
#    2204     # This means that we should pause again after a set next statement.
#
# File ~/miniconda3/envs/cs598-pyhealth/lib/python3.13/site-packages/debugpy/_vendored/pydevd/pydevd.py:2268, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2265                 queue.put(internal_cmd)
#    2266                 wait_timeout = TIMEOUT_FAST
# -> 2268         notify_event.wait(wait_timeout)
#    2269         notify_event.clear()
#    2271 finally:
#
# File ~/miniconda3/envs/cs598-pyhealth/lib/python3.13/threading.py:660, in Event.wait(self, timeout)
#     658 signaled = self._flag
#     659 if not signaled:
# --> 660     signaled = self._cond.wait(timeout)
#     661 return signaled
#
# File ~/miniconda3/envs/cs598-pyhealth/lib/python3.13/threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 2) Configure Paths

# %%
PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "PyHealth").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

print("PROJECT_ROOT:", PROJECT_ROOT)

# %% [markdown]
# ## 3) Declare the dataset CheXpert Dataset
# The CheXpert dataset `df_chexpert_plus_240401.csv` can be downloaded at:
# https://stanfordaimi.azurewebsites.net/datasets/5158c524-d3ab-4e02-96e9-6ee9efc110a1
#
# You may have to create and account and accept Terms of Agreement to access.

# %%
cheXpert = RexKGCheXpertDataset(
    root=str(PROJECT_ROOT / "data" / "df_chexpert_plus_240401.csv")
    tables=[
        "path_to_image",
        "path_to_dcm",
        "frontal_lateral",
        "ap_pa",
        "deid_patient_id",
        "patient_report_date_order",
        "report",
        "section_narrative",
        "section_clinical_history",
        "section_history",
        "section_comparison",
        "section_technique",
        "section_procedure_comments",
        "section_findings",
        "section_impression",
        "section_end_of_impression",
        "section_summary",
        "section_accession_number",
        "age",
        "sex",
        "race",
        "ethnicity",
        "interpreter_needed",
        "insurance_type",
        "recent_bmi",
        "deceased",
        "split",
    ],
    dev=False
)
